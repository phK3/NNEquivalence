# %% [markdown]
# # Demonstration of NN-Equivalence Tool #
#
# In this notebook, we run through an example of verifying equivalence for two neural networks.

# %%
from performance import Encoder

# %% [markdown]
# Example neural networks are stored in the `ExampleNNs` directory.
# We use the balance scale network, because they are very small and therefore their encodings are not too long, so we can print them.
#
# In this case the test network is a version of the reference network with the value of few weights being manually altered.

# %%
reference = 'ExampleNNs/balance_scale_lin.h5'
test = 'ExampleNNs/balance_scale_lin2.h5'

# %% [markdown]
# ## Verifying Top-2-Equivalence
#
# We want to verify top-2-equivalence.
#
# The mode is named `one_hot_partial_top_2`, because we use a partial permutation matrix to retrieve activations of the 2 most likely classes from the test network.
# For the reference network, the partial permutation matrix needed to retrieve only the top output has only one row and is therefore a one hot vector.
#
# For mode-names corresponding to top-k-equivalence for other values of k, the number at the end of the mode-name can be changed.
#
# For $\varepsilon$-equivalence, modes `optimize_diff_[manhattan | chebyshev]` can be used.

# %%
mode = 'one_hot_partial_top_2'

# %% [markdown]
# We need to specify lower and upper bounds on the inputs.

# %%
input_los = [0,0,0,0]
input_his = [5,5,5,5]

# %% [markdown]
# Instantiate an `Encoder` object and tell it to encode equivalence between the reference and the test network.
#
# I did not remove the debug output for the cell below. It can be ignored.

# %%
enc = Encoder()
enc.encode_equiv(reference, test, input_los, input_his, mode)
# Out:
# ### Vars ###
# ### Constraints ###
# A_pi_3_0 = 0 --> (A_x_2_0 + 0.0001) <= A_top_3_0
# A_pi_3_1 = 0 --> (A_x_2_1 + 0.0001) <= A_top_3_0
# A_pi_3_2 = 0 --> (A_x_2_2 + 0.0001) <= A_top_3_0

# %% [markdown]
# We want to restrict the input-domain for the equivalence verification to points within a radius of 5, measured in the manhattan distance.

# %%
center = [5,5,0,0]
radius = 5

enc.add_input_radius(center, radius, metric='manhattan')

# %% [markdown]
# We print the encoding of this verification instance.
#
# The first section of the output contains the variables of the encoding with intervals describing their lower and upper bounds.
# Note, that all variables other than the input variables are set to default bounds, as we didn't perform bounds optimization yet.
#
# Every variable has a (sometimes empty) prefix, indicating, to which network it belongs.
# * Variables belonging to the input layer are only encoded once and don't have a net-prefix.
# * Variables belonging to the reference network are prefixed with 'A'
# * Variables belonging to the test network are prefixed with 'B'
# * Variables belonging to the encoding of the equivalence property are prefixed with 'E'
#
# Furthermore every variable has two indices.
# Variable `A_x_0_3` for example belongs to the first (the 0th) layer of the reference network and is in the 4th row of that layer.
# For variables not belonging to layered architecture of a network, the indices don't have a special meaning.
#
# Variables named `i` are input variables, while variables named `x` typically represent linear combinations of values of neurons in the preceding layer.
# Variables named `d` represent binary variables.
#
# Later we are interested in maximizing the variable `E_diff_0_2`, which contains the violation value for our equivalence property.
#
# Constraints can be found in the second section of the output.

# %%
enc.pretty_print()
# Out:
# ### Vars ###
# i_0_0: [0, 5]
# i_0_1: [0, 5]
# i_0_2: [0, 5]
# i_0_3: [0, 5]
# d_0_0: [0, 1]
# d_0_1: [0, 1]
# d_0_2: [0, 1]
# d_0_3: [0, 1]
# abs_0_0: [0, 999999]
# abs_0_1: [0, 999999]
# abs_0_2: [0, 999999]
# abs_0_3: [0, 999999]
# A_x_0_0: [-999999, 999999]
# A_x_0_1: [-999999, 999999]
# A_x_0_2: [-999999, 999999]
# A_x_0_3: [-999999, 999999]
# A_d_0_0: [0, 1]
# A_d_0_1: [0, 1]
# A_d_0_2: [0, 1]
# A_d_0_3: [0, 1]
# A_o_0_0: [0, 999999]
# A_o_0_1: [0, 999999]
# A_o_0_2: [0, 999999]
# A_o_0_3: [0, 999999]
# A_x_1_0: [-999999, 999999]
# A_x_1_1: [-999999, 999999]
# A_x_1_2: [-999999, 999999]
# A_x_1_3: [-999999, 999999]
# A_d_1_0: [0, 1]
# A_d_1_1: [0, 1]
# A_d_1_2: [0, 1]
# A_d_1_3: [0, 1]
# A_o_1_0: [0, 999999]
# A_o_1_1: [0, 999999]
# A_o_1_2: [0, 999999]
# A_o_1_3: [0, 999999]
# A_x_2_0: [-999999, 999999]
# A_x_2_1: [-999999, 999999]
# A_x_2_2: [-999999, 999999]
# A_y_0_0: [-999999, 999999]
# A_y_1_0: [-999999, 999999]
# A_y_2_0: [-999999, 999999]
# A_top_3_0: [-999999, 999999]
# A_pi_3_0: [0, 1]
# A_pi_3_1: [0, 1]
# A_pi_3_2: [0, 1]
# B_x_0_0: [-999999, 999999]
# B_x_0_1: [-999999, 999999]
# B_x_0_2: [-999999, 999999]
# B_x_0_3: [-999999, 999999]
# B_d_0_0: [0, 1]
# B_d_0_1: [0, 1]
# B_d_0_2: [0, 1]
# B_d_0_3: [0, 1]
# B_o_0_0: [0, 999999]
# B_o_0_1: [0, 999999]
# B_o_0_2: [0, 999999]
# B_o_0_3: [0, 999999]
# B_x_1_0: [-999999, 999999]
# B_x_1_1: [-999999, 999999]
# B_x_1_2: [-999999, 999999]
# B_x_1_3: [-999999, 999999]
# B_d_1_0: [0, 1]
# B_d_1_1: [0, 1]
# B_d_1_2: [0, 1]
# B_d_1_3: [0, 1]
# B_o_1_0: [0, 999999]
# B_o_1_1: [0, 999999]
# B_o_1_2: [0, 999999]
# B_o_1_3: [0, 999999]
# B_x_2_0: [-999999, 999999]
# B_x_2_1: [-999999, 999999]
# B_x_2_2: [-999999, 999999]
# E_top_0_0: [-999999, 999999]
# Eoh_y_0_0: [-999999, 999999]
# Eoh_y_1_0: [-999999, 999999]
# Eoh_y_2_0: [-999999, 999999]
# E_pi_0_0: [0, 1]
# E_pi_1_0: [0, 1]
# E_pi_2_0: [0, 1]
# E_pi_0_1: [0, 1]
# E_pi_1_1: [0, 1]
# E_pi_2_1: [0, 1]
# E_set_1_0: [0, 1]
# E_set_1_1: [0, 1]
# E_set_1_2: [0, 1]
# E_y_0_0: [-999999, 999999]
# E_y_1_0: [-999999, 999999]
# E_y_2_0: [-999999, 999999]
# E_y_0_1: [-999999, 999999]
# E_y_1_1: [-999999, 999999]
# E_y_2_1: [-999999, 999999]
# E_o_1_0: [-999999, 999999]
# E_o_1_1: [-999999, 999999]
# E_diff_0_2: [-999999, 999999]
# ### Constraints ###
# abs_0_0 =  |(i_0_0 + (- 5))|
# abs_0_1 =  |(i_0_1 + (- 5))|
# abs_0_2 =  |(i_0_2 + (- 0))|
# abs_0_3 =  |(i_0_3 + (- 0))|
# 5.0 >= (abs_0_0 + abs_0_1 + abs_0_2 + abs_0_3)
# (A_x_0_0 = ((-0.6379809 * i_0_0) + (0.07340504 * i_0_1) + (-0.21287224 * i_0_2) + (0.46451607 * i_0_3) + -0.21016687))
# (A_x_0_1 = ((-0.7547593 * i_0_0) + (0.15725836 * i_0_1) + (0.66521823 * i_0_2) + (0.31605786 * i_0_3) + 0.085867114))
# (A_x_0_2 = ((-0.048892193 * i_0_0) + (-0.35396737 * i_0_1) + (0.122523874 * i_0_2) + (0.57615966 * i_0_3) + 0.23653667))
# (A_x_0_3 = ((0.42926562 * i_0_0) + (0.9992404 * i_0_1) + (-0.37910253 * i_0_2) + (0.016789414 * i_0_3) + 0.10610554))
# A_o_0_0 =  ReLU(A_x_0_0)
# A_o_0_1 =  ReLU(A_x_0_1)
# A_o_0_2 =  ReLU(A_x_0_2)
# A_o_0_3 =  ReLU(A_x_0_3)
# (A_x_1_0 = ((0.62615985 * A_o_0_0) + (0.039529245 * A_o_0_1) + (-0.5513049 * A_o_0_2) + (0.6923107 * A_o_0_3) + 0.022550788))
# (A_x_1_1 = ((-0.12951012 * A_o_0_0) + (0.22551966 * A_o_0_1) + (0.2794804 * A_o_0_2) + (-0.018626418 * A_o_0_3) + -0.18887858))
# (A_x_1_2 = ((-0.25555655 * A_o_0_0) + (1.0147316 * A_o_0_1) + (0.92903113 * A_o_0_2) + (-0.23300982 * A_o_0_3) + -0.103333026))
# (A_x_1_3 = ((-0.40417266 * A_o_0_0) + (-0.76209813 * A_o_0_1) + (-0.6888845 * A_o_0_2) + (0.59146595 * A_o_0_3) + 0.1664231))
# A_o_1_0 =  ReLU(A_x_1_0)
# A_o_1_1 =  ReLU(A_x_1_1)
# A_o_1_2 =  ReLU(A_x_1_2)
# A_o_1_3 =  ReLU(A_x_1_3)
# (A_x_2_0 = ((0.9111556 * A_o_1_0) + (-0.5999428 * A_o_1_1) + (-0.724907 * A_o_1_2) + (1.2218964 * A_o_1_3) + 0.105831355))
# (A_x_2_1 = ((0.5837674 * A_o_1_0) + (0.55900586 * A_o_1_1) + (-0.22997126 * A_o_1_2) + (-0.35976943 * A_o_1_3) + -0.16196148))
# (A_x_2_2 = ((-0.16923249 * A_o_1_0) + (0.49686074 * A_o_1_1) + (0.8652662 * A_o_1_2) + (0.08620654 * A_o_1_3) + 0.07103808))
# (1 = (A_pi_3_0 + A_pi_3_1 + A_pi_3_2))
# A_y_0_0 = BinMult(A_pi_3_0, A_x_2_0)
# A_y_1_0 = BinMult(A_pi_3_1, A_x_2_1)
# A_y_2_0 = BinMult(A_pi_3_2, A_x_2_2)
# (A_top_3_0 = (A_y_0_0 + A_y_1_0 + A_y_2_0))
# A_pi_3_0 = 0 --> (A_x_2_0 + 0.0001) <= A_top_3_0
# A_pi_3_1 = 0 --> (A_x_2_1 + 0.0001) <= A_top_3_0
# A_pi_3_2 = 0 --> (A_x_2_2 + 0.0001) <= A_top_3_0
# A_top_3_0 in top_1(A_x_2_0, A_x_2_1, A_x_2_2)
# (B_x_0_0 = ((1.0 * i_0_0) + (0.07340504 * i_0_1) + (-0.21287224 * i_0_2) + (0.46451607 * i_0_3) + -0.21016687))
# (B_x_0_1 = ((-0.7547593 * i_0_0) + (1.0 * i_0_1) + (0.66521823 * i_0_2) + (0.31605786 * i_0_3) + 0.085867114))
# (B_x_0_2 = ((1.0 * i_0_0) + (-0.35396737 * i_0_1) + (0.122523874 * i_0_2) + (0.57615966 * i_0_3) + 0.23653667))
# (B_x_0_3 = ((0.42926562 * i_0_0) + (1.0 * i_0_1) + (-0.37910253 * i_0_2) + (0.016789414 * i_0_3) + 0.10610554))
# B_o_0_0 =  ReLU(B_x_0_0)
# B_o_0_1 =  ReLU(B_x_0_1)
# B_o_0_2 =  ReLU(B_x_0_2)
# B_o_0_3 =  ReLU(B_x_0_3)
# (B_x_1_0 = ((0.62615985 * B_o_0_0) + (0.039529245 * B_o_0_1) + (-0.5513049 * B_o_0_2) + (0.6923107 * B_o_0_3) + 0.022550788))
# (B_x_1_1 = ((-0.12951012 * B_o_0_0) + (0.22551966 * B_o_0_1) + (0.2794804 * B_o_0_2) + (-0.018626418 * B_o_0_3) + -0.18887858))
# (B_x_1_2 = ((-0.25555655 * B_o_0_0) + (1.0147316 * B_o_0_1) + (0.92903113 * B_o_0_2) + (-0.23300982 * B_o_0_3) + -0.103333026))
# (B_x_1_3 = ((-0.40417266 * B_o_0_0) + (-0.76209813 * B_o_0_1) + (-0.6888845 * B_o_0_2) + (0.59146595 * B_o_0_3) + 0.1664231))
# B_o_1_0 =  ReLU(B_x_1_0)
# B_o_1_1 =  ReLU(B_x_1_1)
# B_o_1_2 =  ReLU(B_x_1_2)
# B_o_1_3 =  ReLU(B_x_1_3)
# (B_x_2_0 = ((0.9111556 * B_o_1_0) + (-0.5999428 * B_o_1_1) + (-0.724907 * B_o_1_2) + (1.2218964 * B_o_1_3) + 0.105831355))
# (B_x_2_1 = ((0.5837674 * B_o_1_0) + (0.55900586 * B_o_1_1) + (-0.22997126 * B_o_1_2) + (-0.35976943 * B_o_1_3) + -0.16196148))
# (B_x_2_2 = ((-0.16923249 * B_o_1_0) + (0.49686074 * B_o_1_1) + (0.8652662 * B_o_1_2) + (0.08620654 * B_o_1_3) + 0.07103808))
# Eoh_y_0_0 = BinMult(A_pi_3_0, B_x_2_0)
# Eoh_y_1_0 = BinMult(A_pi_3_1, B_x_2_1)
# Eoh_y_2_0 = BinMult(A_pi_3_2, B_x_2_2)
# (E_top_0_0 = (Eoh_y_0_0 + Eoh_y_1_0 + Eoh_y_2_0))
# E_y_0_0 = BinMult(E_pi_0_0, B_x_2_0)
# E_y_1_0 = BinMult(E_pi_1_0, B_x_2_1)
# E_y_2_0 = BinMult(E_pi_2_0, B_x_2_2)
# E_y_0_1 = BinMult(E_pi_0_1, B_x_2_0)
# E_y_1_1 = BinMult(E_pi_1_1, B_x_2_1)
# E_y_2_1 = BinMult(E_pi_2_1, B_x_2_2)
# (E_o_1_0 = (E_y_0_0 + E_y_1_0 + E_y_2_0))
# (E_o_1_1 = (E_y_0_1 + E_y_1_1 + E_y_2_1))
# (1 = (E_pi_0_0 + E_pi_1_0 + E_pi_2_0))
# (1 = (E_pi_0_1 + E_pi_1_1 + E_pi_2_1))
# (E_set_1_0 = (E_pi_0_0 + E_pi_0_1))
# 1 >= E_set_1_0
# (E_set_1_1 = (E_pi_1_0 + E_pi_1_1))
# 1 >= E_set_1_1
# (E_set_1_2 = (E_pi_2_0 + E_pi_2_1))
# 1 >= E_set_1_2
# E_o_1_0 >= E_o_1_1
# E_set_1_0 = 0 --> B_x_2_0 <= E_o_1_1
# E_set_1_1 = 0 --> B_x_2_1 <= E_o_1_1
# E_set_1_2 = 0 --> B_x_2_2 <= E_o_1_1
# E_top_0_0 in extreme(B_x_2_0, B_x_2_1, B_x_2_2)
# E_o_1_0 in top_1(B_x_2_0, B_x_2_1, B_x_2_2)
# E_o_1_1 in top_2(B_x_2_0, B_x_2_1, B_x_2_2)
# (E_diff_0_2 = (E_o_1_1 + (- E_top_0_0)))

# %% [markdown]
# Now we perform bounds tightening by interval arithmetic and by solving smaller sub-problems.
#
# The output is the Gurobi-log for the subproblems solved.

# %%
enc.optimize_constraints()
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-27
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0xda8fd283
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [2e-02, 7e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 4.5258605
#
# Root relaxation: objective 5.759716e+00, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    5.75972    0    2    4.52586    5.75972  27.3%     -    0s
# H    0     0                       5.0767234    5.75972  13.5%     -    0s
#      0     0     cutoff    0         5.07672    5.07672  0.00%     -    0s
#
# Cutting planes:
#   Implied bound: 1
#   MIR: 2
#   Flow cover: 2
#
# Explored 1 nodes (8 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.07672 4.52586
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.076723421703e+00, best bound 5.076723421703e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x57c86c03
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 7e+00]
#   RHS range        [2e-02, 7e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -1.7640250
#
# Root relaxation: objective -1.847896e+00, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -1.8478958   -1.84790  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -1.8479 -1.76403
# No other solutions better than -1.8479
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.847895827537e+00, best bound -1.847895827537e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0xa93140c8
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [6e-01, 7e+00]
#   RHS range        [9e-02, 7e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 1.7191472
#
# Root relaxation: objective 1.843687e+00, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       1.8436871    1.84369  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 1.84369 1.71915
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.843687119551e+00, best bound 1.843687119551e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x736a7e23
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [6e-01, 7e+00]
#   RHS range        [9e-02, 7e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -0.2991076
#
# Root relaxation: objective -5.136378e-01, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.51364    0    2   -0.29911   -0.51364  71.7%     -    0s
# H    0     0                      -0.3248596   -0.51364  58.1%     -    0s
#      0     0     cutoff    0        -0.32486   -0.32486  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 1
#   Flow cover: 1
#   RLT: 1
#   Relax-and-lift: 1
#
# Explored 1 nodes (11 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -0.32486 -0.299108
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -3.248596269891e-01, best bound -3.248596269891e-01, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x5330df77
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 9e+00]
#   RHS range        [9e-02, 7e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 7.8389428
#
# Root relaxation: objective 8.159866e+00, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       8.1598656    8.15987  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 8.15987 7.83894
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.159865636119e+00, best bound 8.159865636119e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0xa9d1e5de
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 9e+00]
#   RHS range        [9e-02, 7e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -1.5167920
#
# Root relaxation: objective -2.065812e+00, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -2.06581    0    1   -1.51679   -2.06581  36.2%     -    0s
# H    0     0                      -1.8044072   -2.06581  14.5%     -    0s
#
# Cutting planes:
#   MIR: 2
#   Flow cover: 1
#
# Explored 1 nodes (4 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -1.80441 -1.51679
# No other solutions better than -1.80441
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.804407192749e+00, best bound -1.804407192749e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x7d46bc21
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [9e-02, 7e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 3.7890098
#
# Root relaxation: objective 4.484385e+00, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       4.4843848    4.48438  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 4.48438 3.78901
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.484384754976e+00, best bound 4.484384754976e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x05596344
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 7e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 8e+00]
#   RHS range        [9e-02, 7e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -6.4702663
#
# Root relaxation: objective -7.003215e+00, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -7.00321    0    1   -6.47027   -7.00321  8.24%     -    0s
# *    0     0               0      -6.6312613   -6.63126  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -6.63126 -6.47027
# No other solutions better than -6.63126
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.631261264249e+00, best bound -6.631261264249e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x59dca569
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-01, 1e+01]
#   RHS range        [2e-02, 8e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 8.5199027
#
# Root relaxation: objective 1.021097e+01, 0 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      10.2109699   10.21097  0.00%     -    0s
#
# Explored 1 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 10.211 8.5199
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.021096986925e+01, best bound 1.021096986925e+01, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0xbb4a8bef
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-01, 1e+01]
#   RHS range        [2e-02, 8e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -1.4018540
#
# Root relaxation: objective -6.915419e+00, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -6.9154190   -6.91542  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -6.91542 -1.40185
# No other solutions better than -6.91542
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.915419027782e+00, best bound -6.915419027782e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x8ac52e57
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-01, 8e+00]
#   RHS range        [2e-02, 8e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 2.6280798
#
# Root relaxation: objective 2.760701e+00, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.76070    0    1    2.62808    2.76070  5.05%     -    0s
#      0     0     cutoff    0         2.62808    2.62808  0.00%     -    0s
#
# Cutting planes:
#   MIR: 3
#
# Explored 1 nodes (11 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 2.62808
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.628079801186e+00, best bound 2.628079801186e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x597bc1e2
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-01, 8e+00]
#   RHS range        [2e-02, 8e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -0.2555078
#
# Root relaxation: objective -1.544691e+00, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -1.54469    0    2   -0.25551   -1.54469   505%     -    0s
# H    0     0                      -0.3266378   -1.54469   373%     -    0s
#      0     0   -1.04456    0    1   -0.32664   -1.04456   220%     -    0s
# *    0     0               0      -1.0425375   -1.04254  0.00%     -    0s
#
# Cutting planes:
#   MIR: 1
#   Flow cover: 3
#   Relax-and-lift: 1
#   PSD: 1
#
# Explored 1 nodes (18 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: -1.04254 -0.326638 -0.255508
# No other solutions better than -1.04254
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.042537455728e+00, best bound -1.042537455728e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x0b2864a5
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-01, 8e+00]
#   RHS range        [2e-02, 8e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 3.8383530
#
# Root relaxation: objective 8.071058e+00, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    8.07106    0    1    3.83835    8.07106   110%     -    0s
# H    0     0                       8.0475498    8.07106  0.29%     -    0s
#      0     0    8.07106    0    1    8.04755    8.07106  0.29%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 8.04755 3.83835
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.047549796665e+00, best bound 8.047549796665e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x35695073
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 8e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [3e-01, 8e+00]
#   RHS range        [2e-02, 8e+00]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -0.6744053
#
# Root relaxation: objective -7.300947e-01, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -0.7300947   -0.73009  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -0.730095 -0.674405
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -7.300947135949e-01, best bound -7.300947135949e-01, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0xe3546e0c
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [2e-02, 1e+01]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 6.4131624
#
# Root relaxation: objective 6.505662e+00, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    6.50566    0    1    6.41316    6.50566  1.44%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 6.41316
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.413162396060e+00, best bound 6.413162396060e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x4fa6de11
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [2e-02, 1e+01]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -1.0013404
#
# Root relaxation: objective -1.180203e+00, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -1.1802032   -1.18020  0.00%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -1.1802 -1.00134
# No other solutions better than -1.1802
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.180203163344e+00, best bound -1.180203163344e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x1d54b1e0
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [9e-02, 1e+01]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 2.3677517
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0         2.36775    2.36775  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 2.36775
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.367751742917e+00, best bound 2.367751742917e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x1ef638e5
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+01]
#   RHS range        [9e-02, 1e+01]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -0.0771683
#
# Root relaxation: objective -2.504552e-01, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.25046    0    2   -0.07717   -0.25046   225%     -    0s
# H    0     0                      -0.0938614   -0.25046   167%     -    0s
#      0     0   -0.10800    0    1   -0.09386   -0.10800  15.1%     -    0s
# *    0     0               0      -0.1053829   -0.10538  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 2
#   MIR: 3
#   Flow cover: 4
#   RLT: 1
#
# Explored 1 nodes (14 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: -0.105383 -0.0938614 -0.0771683
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.053828632474e-01, best bound -1.053828632474e-01, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0xc62f0729
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [9e-02, 1e+01]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 10.7278345
#
# Root relaxation: cutoff, 7 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0        10.72783   10.72783  0.00%     -    0s
#
# Explored 1 nodes (7 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 10.7278
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.072783448691e+01, best bound 1.072783448691e+01, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x79af15e8
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [9e-02, 1e+01]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 0.2229944
#
# Root relaxation: objective -3.993495e-01, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -0.39935    0    2    0.22299   -0.39935   279%     -    0s
# H    0     0                       0.1860075   -0.39935   315%     -    0s
#      0     0    0.15842    0    1    0.18601    0.15842  14.8%     -    0s
# *    0     0               0       0.1788253    0.17883  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Implied bound: 1
#   MIR: 4
#   Flow cover: 4
#   RLT: 1
#
# Explored 1 nodes (15 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 3: 0.178825 0.186007 0.222994
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.788253466277e-01, best bound 1.788253466277e-01, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0x105fc9fd
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [9e-02, 1e+01]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective 0.0960274
#
# Root relaxation: objective 8.549336e-01, 9 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.85493    0    1    0.09603    0.85493   790%     -    0s
#      0     0     cutoff    0         0.09603    0.09603  0.00%     -    0s
#
# Explored 1 nodes (11 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 0.0960274
# No other solutions better than 0.0960274
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.602737090850e-02, best bound 9.602737090850e-02, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 29 rows, 17 columns and 73 nonzeros
# Model fingerprint: 0xe3d7d96b
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+01]
#   RHS range        [9e-02, 1e+01]
# Presolve removed 9 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 20 rows, 16 columns, 56 nonzeros
# Variable types: 12 continuous, 4 integer (4 binary)
# Found heuristic solution: objective -8.9597853
#
# Root relaxation: objective -9.044016e+00, 8 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -9.04402    0    1   -8.95979   -9.04402  0.94%     -    0s
#
# Explored 1 nodes (8 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: -8.95979
# No other solutions better than -8.95979
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.959785279949e+00, best bound -8.959785279949e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 24 rows, 17 columns and 63 nonzeros
# Model fingerprint: 0x847518eb
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-01, 1e+01]
#   RHS range        [2e-02, 9e+00]
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 14 columns, 47 nonzeros
# Variable types: 11 continuous, 3 integer (3 binary)
# Found heuristic solution: objective 5.9204587
#
# Root relaxation: objective 5.936924e+00, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0       5.9369238    5.93692  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 5.93692 5.92046
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.936923824552e+00, best bound 5.936923824552e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 24 rows, 17 columns and 63 nonzeros
# Model fingerprint: 0x58e82bbe
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-01, 1e+01]
#   RHS range        [2e-02, 9e+00]
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 14 columns, 47 nonzeros
# Variable types: 11 continuous, 3 integer (3 binary)
# Found heuristic solution: objective -2.5232890
#
# Root relaxation: objective -9.091366e+00, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -9.0913664   -9.09137  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -9.09137 -2.52329
# No other solutions better than -9.09137
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -9.091366373984e+00, best bound -9.091366373984e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 24 rows, 17 columns and 63 nonzeros
# Model fingerprint: 0xae97a477
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-01, 1e+01]
#   RHS range        [2e-02, 9e+00]
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 14 columns, 47 nonzeros
# Variable types: 11 continuous, 3 integer (3 binary)
# Found heuristic solution: objective 3.5365749
#
# Root relaxation: objective 3.595526e+00, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    3.59553    0    1    3.53657    3.59553  1.67%     -    0s
# H    0     0                       3.5407091    3.59553  1.55%     -    0s
#
# Cutting planes:
#   MIR: 2
#   Flow cover: 1
#
# Explored 1 nodes (6 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 3.54071 3.53657
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.540709056877e+00, best bound 3.540709056877e+00, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 24 rows, 17 columns and 63 nonzeros
# Model fingerprint: 0xf8060f0d
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-01, 1e+01]
#   RHS range        [2e-02, 9e+00]
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 14 columns, 47 nonzeros
# Variable types: 11 continuous, 3 integer (3 binary)
# Found heuristic solution: objective -0.2555078
#
# Root relaxation: objective -1.361944e+00, 12 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   -1.36194    0    1   -0.25551   -1.36194   433%     -    0s
# H    0     0                      -1.3581350   -1.36194  0.28%     -    0s
#
# Explored 1 nodes (12 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -1.35814 -0.255508
# No other solutions better than -1.35814
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.358135047522e+00, best bound -1.358135047522e+00, gap 0.0000%
# Set parameter TimeLimit to value 20
# Set parameter TimeLimit to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 24 rows, 17 columns and 63 nonzeros
# Model fingerprint: 0xe799bae4
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-01, 1e+01]
#   RHS range        [2e-02, 9e+00]
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 14 columns, 47 nonzeros
# Variable types: 11 continuous, 3 integer (3 binary)
# Found heuristic solution: objective 4.2534833
#
# Root relaxation: objective 1.053113e+01, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   10.53113    0    1    4.25348   10.53113   148%     -    0s
# H    0     0                      10.5299136   10.53113  0.01%     -    0s
#      0     0   10.53113    0    1   10.52991   10.53113  0.01%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 10.5299 4.25348
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.052991359379e+01, best bound 1.052991359379e+01, gap 0.0000%
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 24 rows, 17 columns and 63 nonzeros
# Model fingerprint: 0xf10e5852
# Variable types: 13 continuous, 4 integer (4 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 9e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-01, 1e+01]
#   RHS range        [2e-02, 9e+00]
# Presolve removed 8 rows and 3 columns
# Presolve time: 0.00s
# Presolved: 16 rows, 14 columns, 47 nonzeros
# Variable types: 11 continuous, 3 integer (3 binary)
# Found heuristic solution: objective -0.8541919
#
# Root relaxation: objective -8.595458e-01, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0      -0.8595458   -0.85955  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: -0.859546 -0.854192
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -8.595458150954e-01, best bound -8.595458150954e-01, gap 0.0000%

# %% [markdown]
# We can see, that the bounds of the variables have been tightened.

# %%
enc.pretty_print()
# Out:
# ### Vars ###
# i_0_0: [0, 5]
# i_0_1: [0, 5]
# i_0_2: [0, 5]
# i_0_3: [0, 5]
# d_0_0: [0, 0]
# d_0_1: [0, 0]
# d_0_2: [0, 1]
# d_0_3: [0, 1]
# abs_0_0: [0, 5]
# abs_0_1: [0, 5]
# abs_0_2: [0, 5]
# abs_0_3: [0, 5]
# A_x_0_0: [-4.464432448148727, 2.4794387072324753]
# A_x_0_1: [-3.687929444015026, 5.7785393968224525]
# A_x_0_2: [-1.7777611389756203, 3.729954317212105]
# A_x_0_3: [-1.7894070968031883, 7.332582697272301]
# A_d_0_0: [0, 1]
# A_d_0_1: [0, 1]
# A_d_0_2: [0, 1]
# A_d_0_3: [0, 1]
# A_o_0_0: [0, 2.4794387072324753]
# A_o_0_1: [0, 5.7785393968224525]
# A_o_0_2: [0, 3.729954317212105]
# A_o_0_3: [0, 7.332582697272301]
# A_x_1_0: [-1.8478958275373936, 5.076723421703085]
# A_x_1_1: [-0.32485962698912885, 1.8436871195505793]
# A_x_1_2: [-1.804407192748503, 8.159865636119198]
# A_x_1_3: [-6.631261264248645, 4.4843847549760945]
# A_d_1_0: [0, 1]
# A_d_1_1: [0, 1]
# A_d_1_2: [0, 1]
# A_d_1_3: [0, 1]
# A_o_1_0: [0, 5.076723421703085]
# A_o_1_1: [0, 1.8436871195505793]
# A_o_1_2: [0, 8.159865636119198]
# A_o_1_3: [0, 4.4843847549760945]
# A_x_2_0: [-6.915419027781918, 10.210969869254601]
# A_x_2_1: [-1.0425374557284912, 2.6280798011861792]
# A_x_2_2: [-0.7300947135949286, 8.047549796665008]
# A_y_0_0: [-6.915419027781918, 10.210969869254601]
# A_y_1_0: [-1.0425374557284912, 2.6280798011861792]
# A_y_2_0: [-0.7300947135949286, 8.047549796665008]
# A_top_3_0: [-0.7300947135949286, 10.210969869254601]
# A_pi_3_0: [0, 1]
# A_pi_3_1: [0, 1]
# A_pi_3_2: [0, 1]
# B_x_0_0: [-1.274528056383133, 7.479438707232475]
# B_x_0_1: [-3.687929444015026, 9.992247588932514]
# B_x_0_2: [-1.5333001762628555, 8.729954317212105]
# B_x_0_3: [-1.7894070968031883, 7.336380705237389]
# B_d_0_0: [0, 1]
# B_d_0_1: [0, 1]
# B_d_0_2: [0, 1]
# B_d_0_3: [0, 1]
# B_o_0_0: [0, 7.479438707232475]
# B_o_0_1: [0, 9.992247588932514]
# B_o_0_2: [0, 8.729954317212105]
# B_o_0_3: [0, 7.336380705237389]
# B_x_1_0: [-1.1802031633442789, 6.413162396059591]
# B_x_1_1: [-0.10538286324740906, 2.367751742916783]
# B_x_1_2: [0.17882534662767036, 10.727834486908648]
# B_x_1_3: [-8.959785279948571, 0.09602737090849656]
# B_d_1_0: [0, 1]
# B_d_1_1: [0, 1]
# B_d_1_2: [1, 1]
# B_d_1_3: [0, 1]
# B_o_1_0: [0, 6.413162396059591]
# B_o_1_1: [0, 2.367751742916783]
# B_o_1_2: [0.17882534662767036, 10.727834486908648]
# B_o_1_3: [0, 0.09602737090849656]
# B_x_2_0: [-9.09136637398367, 5.936923824552427]
# B_x_2_1: [-1.3581350475224918, 3.5407090568772093]
# B_x_2_2: [-0.8595458150954358, 10.529913593790337]
# E_top_0_0: [-9.09136637398367, 10.529913593790337]
# Eoh_y_0_0: [-9.09136637398367, 5.936923824552427]
# Eoh_y_1_0: [-1.3581350475224918, 3.5407090568772093]
# Eoh_y_2_0: [-0.8595458150954358, 10.529913593790337]
# E_pi_0_0: [0, 1]
# E_pi_1_0: [0, 1]
# E_pi_2_0: [0, 1]
# E_pi_0_1: [0, 1]
# E_pi_1_1: [0, 1]
# E_pi_2_1: [0, 1]
# E_set_1_0: [0, 1]
# E_set_1_1: [0, 1]
# E_set_1_2: [0, 1]
# E_y_0_0: [-9.09136637398367, 5.936923824552427]
# E_y_1_0: [-1.3581350475224918, 3.5407090568772093]
# E_y_2_0: [-0.8595458150954358, 10.529913593790337]
# E_y_0_1: [-9.09136637398367, 5.936923824552427]
# E_y_1_1: [-1.3581350475224918, 3.5407090568772093]
# E_y_2_1: [-0.8595458150954358, 10.529913593790337]
# E_o_1_0: [-0.8595458150954358, 10.529913593790337]
# E_o_1_1: [-1.3581350475224918, 5.936923824552427]
# E_diff_0_2: [-11.888048641312828, 15.028290198536098]
# ### Constraints ###
# abs_0_0 =  |(i_0_0 + (- 5))|
# abs_0_1 =  |(i_0_1 + (- 5))|
# abs_0_2 =  |(i_0_2 + (- 0))|
# abs_0_3 =  |(i_0_3 + (- 0))|
# 5.0 >= (abs_0_0 + abs_0_1 + abs_0_2 + abs_0_3)
# (A_x_0_0 = ((-0.6379809 * i_0_0) + (0.07340504 * i_0_1) + (-0.21287224 * i_0_2) + (0.46451607 * i_0_3) + -0.21016687))
# (A_x_0_1 = ((-0.7547593 * i_0_0) + (0.15725836 * i_0_1) + (0.66521823 * i_0_2) + (0.31605786 * i_0_3) + 0.085867114))
# (A_x_0_2 = ((-0.048892193 * i_0_0) + (-0.35396737 * i_0_1) + (0.122523874 * i_0_2) + (0.57615966 * i_0_3) + 0.23653667))
# (A_x_0_3 = ((0.42926562 * i_0_0) + (0.9992404 * i_0_1) + (-0.37910253 * i_0_2) + (0.016789414 * i_0_3) + 0.10610554))
# A_o_0_0 =  ReLU(A_x_0_0)
# A_o_0_1 =  ReLU(A_x_0_1)
# A_o_0_2 =  ReLU(A_x_0_2)
# A_o_0_3 =  ReLU(A_x_0_3)
# (A_x_1_0 = ((0.62615985 * A_o_0_0) + (0.039529245 * A_o_0_1) + (-0.5513049 * A_o_0_2) + (0.6923107 * A_o_0_3) + 0.022550788))
# (A_x_1_1 = ((-0.12951012 * A_o_0_0) + (0.22551966 * A_o_0_1) + (0.2794804 * A_o_0_2) + (-0.018626418 * A_o_0_3) + -0.18887858))
# (A_x_1_2 = ((-0.25555655 * A_o_0_0) + (1.0147316 * A_o_0_1) + (0.92903113 * A_o_0_2) + (-0.23300982 * A_o_0_3) + -0.103333026))
# (A_x_1_3 = ((-0.40417266 * A_o_0_0) + (-0.76209813 * A_o_0_1) + (-0.6888845 * A_o_0_2) + (0.59146595 * A_o_0_3) + 0.1664231))
# A_o_1_0 =  ReLU(A_x_1_0)
# A_o_1_1 =  ReLU(A_x_1_1)
# A_o_1_2 =  ReLU(A_x_1_2)
# A_o_1_3 =  ReLU(A_x_1_3)
# (A_x_2_0 = ((0.9111556 * A_o_1_0) + (-0.5999428 * A_o_1_1) + (-0.724907 * A_o_1_2) + (1.2218964 * A_o_1_3) + 0.105831355))
# (A_x_2_1 = ((0.5837674 * A_o_1_0) + (0.55900586 * A_o_1_1) + (-0.22997126 * A_o_1_2) + (-0.35976943 * A_o_1_3) + -0.16196148))
# (A_x_2_2 = ((-0.16923249 * A_o_1_0) + (0.49686074 * A_o_1_1) + (0.8652662 * A_o_1_2) + (0.08620654 * A_o_1_3) + 0.07103808))
# (1 = (A_pi_3_0 + A_pi_3_1 + A_pi_3_2))
# A_y_0_0 = BinMult(A_pi_3_0, A_x_2_0)
# A_y_1_0 = BinMult(A_pi_3_1, A_x_2_1)
# A_y_2_0 = BinMult(A_pi_3_2, A_x_2_2)
# (A_top_3_0 = (A_y_0_0 + A_y_1_0 + A_y_2_0))
# A_pi_3_0 = 0 --> (A_x_2_0 + 0.0001) <= A_top_3_0
# A_pi_3_1 = 0 --> (A_x_2_1 + 0.0001) <= A_top_3_0
# A_pi_3_2 = 0 --> (A_x_2_2 + 0.0001) <= A_top_3_0
# A_top_3_0 in top_1(A_x_2_0, A_x_2_1, A_x_2_2)
# (B_x_0_0 = ((1.0 * i_0_0) + (0.07340504 * i_0_1) + (-0.21287224 * i_0_2) + (0.46451607 * i_0_3) + -0.21016687))
# (B_x_0_1 = ((-0.7547593 * i_0_0) + (1.0 * i_0_1) + (0.66521823 * i_0_2) + (0.31605786 * i_0_3) + 0.085867114))
# (B_x_0_2 = ((1.0 * i_0_0) + (-0.35396737 * i_0_1) + (0.122523874 * i_0_2) + (0.57615966 * i_0_3) + 0.23653667))
# (B_x_0_3 = ((0.42926562 * i_0_0) + (1.0 * i_0_1) + (-0.37910253 * i_0_2) + (0.016789414 * i_0_3) + 0.10610554))
# B_o_0_0 =  ReLU(B_x_0_0)
# B_o_0_1 =  ReLU(B_x_0_1)
# B_o_0_2 =  ReLU(B_x_0_2)
# B_o_0_3 =  ReLU(B_x_0_3)
# (B_x_1_0 = ((0.62615985 * B_o_0_0) + (0.039529245 * B_o_0_1) + (-0.5513049 * B_o_0_2) + (0.6923107 * B_o_0_3) + 0.022550788))
# (B_x_1_1 = ((-0.12951012 * B_o_0_0) + (0.22551966 * B_o_0_1) + (0.2794804 * B_o_0_2) + (-0.018626418 * B_o_0_3) + -0.18887858))
# (B_x_1_2 = ((-0.25555655 * B_o_0_0) + (1.0147316 * B_o_0_1) + (0.92903113 * B_o_0_2) + (-0.23300982 * B_o_0_3) + -0.103333026))
# (B_x_1_3 = ((-0.40417266 * B_o_0_0) + (-0.76209813 * B_o_0_1) + (-0.6888845 * B_o_0_2) + (0.59146595 * B_o_0_3) + 0.1664231))
# B_o_1_0 =  ReLU(B_x_1_0)
# B_o_1_1 =  ReLU(B_x_1_1)
# B_o_1_2 =  ReLU(B_x_1_2)
# B_o_1_3 =  ReLU(B_x_1_3)
# (B_x_2_0 = ((0.9111556 * B_o_1_0) + (-0.5999428 * B_o_1_1) + (-0.724907 * B_o_1_2) + (1.2218964 * B_o_1_3) + 0.105831355))
# (B_x_2_1 = ((0.5837674 * B_o_1_0) + (0.55900586 * B_o_1_1) + (-0.22997126 * B_o_1_2) + (-0.35976943 * B_o_1_3) + -0.16196148))
# (B_x_2_2 = ((-0.16923249 * B_o_1_0) + (0.49686074 * B_o_1_1) + (0.8652662 * B_o_1_2) + (0.08620654 * B_o_1_3) + 0.07103808))
# Eoh_y_0_0 = BinMult(A_pi_3_0, B_x_2_0)
# Eoh_y_1_0 = BinMult(A_pi_3_1, B_x_2_1)
# Eoh_y_2_0 = BinMult(A_pi_3_2, B_x_2_2)
# (E_top_0_0 = (Eoh_y_0_0 + Eoh_y_1_0 + Eoh_y_2_0))
# E_y_0_0 = BinMult(E_pi_0_0, B_x_2_0)
# E_y_1_0 = BinMult(E_pi_1_0, B_x_2_1)
# E_y_2_0 = BinMult(E_pi_2_0, B_x_2_2)
# E_y_0_1 = BinMult(E_pi_0_1, B_x_2_0)
# E_y_1_1 = BinMult(E_pi_1_1, B_x_2_1)
# E_y_2_1 = BinMult(E_pi_2_1, B_x_2_2)
# (E_o_1_0 = (E_y_0_0 + E_y_1_0 + E_y_2_0))
# (E_o_1_1 = (E_y_0_1 + E_y_1_1 + E_y_2_1))
# (1 = (E_pi_0_0 + E_pi_1_0 + E_pi_2_0))
# (1 = (E_pi_0_1 + E_pi_1_1 + E_pi_2_1))
# (E_set_1_0 = (E_pi_0_0 + E_pi_0_1))
# 1 >= E_set_1_0
# (E_set_1_1 = (E_pi_1_0 + E_pi_1_1))
# 1 >= E_set_1_1
# (E_set_1_2 = (E_pi_2_0 + E_pi_2_1))
# 1 >= E_set_1_2
# E_o_1_0 >= E_o_1_1
# E_set_1_0 = 0 --> B_x_2_0 <= E_o_1_1
# E_set_1_1 = 0 --> B_x_2_1 <= E_o_1_1
# E_set_1_2 = 0 --> B_x_2_2 <= E_o_1_1
# E_top_0_0 in extreme(B_x_2_0, B_x_2_1, B_x_2_2)
# E_o_1_0 in top_1(B_x_2_0, B_x_2_1, B_x_2_2)
# E_o_1_1 in top_2(B_x_2_0, B_x_2_1, B_x_2_2)
# (E_diff_0_2 = (E_o_1_1 + (- E_top_0_0)))

# %% [markdown]
# Now we use Gurobi to optimize the encoding.
#
# At the very top of the log, we can see the size of the encoding.
# A few lines below is the size of the mixed integer linear program (MILP) after application of Gurobi's presolve routine.
#
# The column `Incumbent` contains the best (in this case the maximal) value of the objective function (here the variable `E_diff_0_2` representing the violation score of top-2-equivalence).
# The column `BestBd` contains bounds on this value (upper bounds for maximization problems, lower bounds for minimization problems).
#
# The final solution is printed at the bottom.
# As it is greater than zero, the test network is not top-2-equivalent to the reference network.

# %%
model = enc.create_gurobi_model()
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 187 rows, 95 columns and 484 nonzeros
# Model fingerprint: 0xa7e4f7c0
# Variable types: 63 continuous, 32 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e-01, 2e+01]
#   RHS range        [1e-04, 2e+01]
# Presolve removed 59 rows and 21 columns
# Presolve time: 0.00s
# Presolved: 128 rows, 74 columns, 404 nonzeros
# Variable types: 52 continuous, 22 integer (22 binary)
#
# Root relaxation: objective 1.121046e+01, 69 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   11.21046    0   15          -   11.21046      -     -    0s
# H    0     0                       0.5384114   11.21046  1982%     -    0s
#      0     0    7.61319    0   16    0.53841    7.61319  1314%     -    0s
#      0     0    6.98558    0   16    0.53841    6.98558  1197%     -    0s
#      0     0    6.83435    0   13    0.53841    6.83435  1169%     -    0s
#      0     0    6.54554    0   16    0.53841    6.54554  1116%     -    0s
#      0     0    6.54554    0   18    0.53841    6.54554  1116%     -    0s
#      0     0    6.54554    0   18    0.53841    6.54554  1116%     -    0s
#      0     0    6.13648    0   10    0.53841    6.13648  1040%     -    0s
# H    0     0                       2.9512734    6.13648   108%     -    0s
#      0     0    5.89207    0    9    2.95127    5.89207   100%     -    0s
#      0     0    5.86740    0    6    2.95127    5.86740  98.8%     -    0s
#      0     0    4.82386    0    8    2.95127    4.82386  63.5%     -    0s
#      0     0    4.82386    0    6    2.95127    4.82386  63.5%     -    0s
#      0     0    4.82386    0    7    2.95127    4.82386  63.5%     -    0s
#      0     0    4.36008    0    7    2.95127    4.36008  47.7%     -    0s
#      0     2    4.36008    0    7    2.95127    4.36008  47.7%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   Cover: 1
#   Implied bound: 1
#   MIR: 1
#   Flow cover: 2
#   RLT: 5
#   Relax-and-lift: 2
#
# Explored 3 nodes (243 simplex iterations) in 0.11 seconds (0.03 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 2.95127 0.538411
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.951273402243e+00, best bound 2.951273402243e+00, gap 0.0000%

# %%
from analysis import get_grb_inputs, calculate_violation

# %% [markdown]
# We can now analyze the counterexample found by Gurobi.
#
# First we retrieve the counterexample. The required method has signature `get_grb_inputs(model, input_size)`.

# %%
ins = get_grb_inputs(model, 4)
print(ins)
# Out:
# [5.0, 5.0, 5.0, 0.0]

# %% [markdown]
# We have a dedicated method to calculate the actual violation to top-k-equivalence.
#
# It takes the found counterexample, the value of k and the paths to the verified neural networks as inputs.

# %%
calculate_violation(ins, reference, test, top_k=2)
# Out:
# 2.9512734022428213

# %% [markdown]
# ## Maximizing Equivalence Radius
#
# This time we want to find a maximal equivalence radius around our centerpoint. First we instantiate a new encoder.

# %%
enc_r = Encoder()
enc_r.encode_equiv(reference, test, input_los, input_his, mode)
# Out:
# ### Vars ###
# ### Constraints ###
# A_pi_3_0 = 0 --> (A_x_2_0 + 0.0001) <= A_top_3_0
# A_pi_3_1 = 0 --> (A_x_2_1 + 0.0001) <= A_top_3_0
# A_pi_3_2 = 0 --> (A_x_2_2 + 0.0001) <= A_top_3_0

# %% [markdown]
# Then we add an input radius, however with `radius_mode='variable'`.
#
# We use an upper bound of 5 on our radius, since we know, that they are not equivalent for this radius from our first verification problem.

# %%
radius_lo = 0
radius_hi = 5

enc_r.add_input_radius(center, radius_hi, metric='manhattan', radius_lo=radius_lo, radius_mode='variable')

# %% [markdown]
# We can then optimize for the radius.
#
# We omit the bounds tightening here, since the balance_scale networks are very small.

# %%
model_r = enc_r.create_gurobi_model()
model_r.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 205 rows, 96 columns and 528 nonzeros
# Model fingerprint: 0xe8e4a876
# Variable types: 64 continuous, 32 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 2e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e-04, 2e+06]
# Presolve removed 74 rows and 22 columns
# Presolve time: 0.01s
# Presolved: 131 rows, 74 columns, 412 nonzeros
# Variable types: 51 continuous, 23 integer (23 binary)
#
# Root relaxation: objective 0.000000e+00, 52 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    4          -    0.00000      -     -    0s
# H    0     0                       2.2720034    0.00000   100%     -    0s
#      0     0    0.00000    0    6    2.27200    0.00000   100%     -    0s
#      0     0    0.00000    0    5    2.27200    0.00000   100%     -    0s
# H    0     0                       1.9979683    0.00000   100%     -    0s
#      0     0    0.35669    0    5    1.99797    0.35669  82.1%     -    0s
#      0     0    0.64484    0    2    1.99797    0.64484  67.7%     -    0s
#      0     0    0.93176    0    1    1.99797    0.93176  53.4%     -    0s
#
# Cutting planes:
#   Gomory: 1
#   RLT: 2
#
# Explored 1 nodes (115 simplex iterations) in 0.06 seconds (0.01 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 1.99797 2.272
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.997968262200e+00, best bound 1.997968262200e+00, gap 0.0000%

# %% [markdown]
# First, we test, if Gurobi found a valid counterexample for radius 1.99797.
#
# As it produces a violation greater than 0.01, it is exceeds our threshold for equivalence and thus is a valid counterexample.
#
# The equivalence threshold, along with other flags and constants can be found in the `flags_constants.py` module.

# %%
ins_r = get_grb_inputs(model_r, 4)
print('Counterexample: ', ins_r)

calculate_violation(ins_r, reference, test, top_k=2)
# Out:
# Counterexample:  [5.0, 5.0, 1.9979682622002195, 0.0]
# 0.009999999989681374

# %% [markdown]
# Now we test, if Gurobi finds, that the two networks are equivalent, when restricting the input-region to a radius just below the smallest radius, for which Gurobi still found a counterexample, whose violation was larger than 0.01.
#
# Within a radius of 1.95, the violation of the equivalence property is indeed almost zero.

# %%
enc_t = Encoder()
enc_t.encode_equiv(reference, test, input_los, input_his, mode)
enc_t.add_input_radius(center, 1.95)
model_t = enc_t.create_gurobi_model()
model_t.optimize()
# Out:
# ### Vars ###
# ### Constraints ###
# A_pi_3_0 = 0 --> (A_x_2_0 + 0.0001) <= A_top_3_0
# A_pi_3_1 = 0 --> (A_x_2_1 + 0.0001) <= A_top_3_0
# A_pi_3_2 = 0 --> (A_x_2_2 + 0.0001) <= A_top_3_0
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 204 rows, 95 columns and 526 nonzeros
# Model fingerprint: 0x6d67559c
# Variable types: 63 continuous, 32 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 2e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [1e-04, 2e+06]
# Presolve removed 141 rows and 56 columns
# Presolve time: 0.00s
# Presolved: 63 rows, 39 columns, 200 nonzeros
# Variable types: 26 continuous, 13 integer (13 binary)
#
# Root relaxation: objective 4.536788e+00, 38 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    4.53679    0   10          -    4.53679      -     -    0s
# H    0     0                      -0.0000000    4.53679      -     -    0s
#      0     0    2.11451    0    9   -0.00000    2.11451      -     -    0s
#      0     0     cutoff    0        -0.00000   -0.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Flow cover: 3
#   Relax-and-lift: 3
#
# Explored 1 nodes (67 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: -0
# No other solutions better than -0
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -0.000000000000e+00, best bound -0.000000000000e+00, gap 0.0000%

# %% [markdown]
# ## Verifying $\epsilon$-Equivalence
#
# To verify $\epsilon$-equivalence, we follow the same pattern as for top-$2$-equivalence above.
#
# First, we specify the mode.
#
# `optimize_diff_manhattan` checks for equivalence using $\| \mathcal{R}(x) - \mathcal{T}(x) \|_1$, while `optimize_diff_chebyshev` checks for equivalence in the sense of $\| \mathcal{R}(x) - \mathcal{T}(x) \|_\infty$.
#
# Below, we are going to check for equivalence in the Chebyshev norm.

# %%
mode = 'optimize_diff_chebyshev'

# %% [markdown]
# Next, we specify the valid input range.

# %%
input_los = [0,0,0,0]
input_his = [5,5,5,5]

# %% [markdown]
# Then, we add the output constraints.

# %%
enc = Encoder()
enc.encode_equiv(reference, test, input_los, input_his, mode)

# %% [markdown]
# Since we don't want to verify a propertey over the entire region of valid inputs, but only a subset, we can specify a radius in either the Manhattan or Chebyshev norm around some center input.
#
# (Considering the Chebyshev norm, we could just set `input_los` and `input_his` to the corresponding values, but for the Manhattan norm, this would not be possible.)

# %%
center = [5,5,0,0]
radius = 5

enc.add_input_radius(center, radius, metric='chebyshev')

# %% [markdown]
# Since we need to check for the largest element-wise absolute difference in the output of the reference and the test network, we compute the absolute differences (the `E_abs_d_0_i` variables) and use a partial permutation matrix, to ensure that `E_o_1_0` contains the largest absolute difference.

# %%
enc.pretty_print()
# Out:
# ### Vars ###
# i_0_0: [0, 5]
# i_0_1: [0, 5]
# i_0_2: [0, 5]
# i_0_3: [0, 5]
# A_x_0_0: [-999999, 999999]
# A_x_0_1: [-999999, 999999]
# A_x_0_2: [-999999, 999999]
# A_x_0_3: [-999999, 999999]
# A_d_0_0: [0, 1]
# A_d_0_1: [0, 1]
# A_d_0_2: [0, 1]
# A_d_0_3: [0, 1]
# A_o_0_0: [0, 999999]
# A_o_0_1: [0, 999999]
# A_o_0_2: [0, 999999]
# A_o_0_3: [0, 999999]
# A_x_1_0: [-999999, 999999]
# A_x_1_1: [-999999, 999999]
# A_x_1_2: [-999999, 999999]
# A_x_1_3: [-999999, 999999]
# A_d_1_0: [0, 1]
# A_d_1_1: [0, 1]
# A_d_1_2: [0, 1]
# A_d_1_3: [0, 1]
# A_o_1_0: [0, 999999]
# A_o_1_1: [0, 999999]
# A_o_1_2: [0, 999999]
# A_o_1_3: [0, 999999]
# A_x_2_0: [-999999, 999999]
# A_x_2_1: [-999999, 999999]
# A_x_2_2: [-999999, 999999]
# B_x_0_0: [-999999, 999999]
# B_x_0_1: [-999999, 999999]
# B_x_0_2: [-999999, 999999]
# B_x_0_3: [-999999, 999999]
# B_d_0_0: [0, 1]
# B_d_0_1: [0, 1]
# B_d_0_2: [0, 1]
# B_d_0_3: [0, 1]
# B_o_0_0: [0, 999999]
# B_o_0_1: [0, 999999]
# B_o_0_2: [0, 999999]
# B_o_0_3: [0, 999999]
# B_x_1_0: [-999999, 999999]
# B_x_1_1: [-999999, 999999]
# B_x_1_2: [-999999, 999999]
# B_x_1_3: [-999999, 999999]
# B_d_1_0: [0, 1]
# B_d_1_1: [0, 1]
# B_d_1_2: [0, 1]
# B_d_1_3: [0, 1]
# B_o_1_0: [0, 999999]
# B_o_1_1: [0, 999999]
# B_o_1_2: [0, 999999]
# B_o_1_3: [0, 999999]
# B_x_2_0: [-999999, 999999]
# B_x_2_1: [-999999, 999999]
# B_x_2_2: [-999999, 999999]
# E_d_0_0: [0, 1]
# E_d_0_1: [0, 1]
# E_d_0_2: [0, 1]
# E_pi_0_0: [0, 1]
# E_pi_1_0: [0, 1]
# E_pi_2_0: [0, 1]
# E_set_1_0: [0, 1]
# E_set_1_1: [0, 1]
# E_set_1_2: [0, 1]
# E_diff_0_0: [-999999, 999999]
# E_diff_0_1: [-999999, 999999]
# E_diff_0_2: [-999999, 999999]
# E_abs_d_0_0: [0, 999999]
# E_abs_d_0_1: [0, 999999]
# E_abs_d_0_2: [0, 999999]
# E_y_0_0: [-999999, 999999]
# E_y_1_0: [-999999, 999999]
# E_y_2_0: [-999999, 999999]
# E_o_1_0: [-999999, 999999]
# E_norm_1_0: [-999999, 999999]
# ### Constraints ###
# (A_x_0_0 = ((-0.6379809 * i_0_0) + (0.07340504 * i_0_1) + (-0.21287224 * i_0_2) + (0.46451607 * i_0_3) + -0.21016687))
# (A_x_0_1 = ((-0.7547593 * i_0_0) + (0.15725836 * i_0_1) + (0.66521823 * i_0_2) + (0.31605786 * i_0_3) + 0.085867114))
# (A_x_0_2 = ((-0.048892193 * i_0_0) + (-0.35396737 * i_0_1) + (0.122523874 * i_0_2) + (0.57615966 * i_0_3) + 0.23653667))
# (A_x_0_3 = ((0.42926562 * i_0_0) + (0.9992404 * i_0_1) + (-0.37910253 * i_0_2) + (0.016789414 * i_0_3) + 0.10610554))
# A_o_0_0 =  ReLU(A_x_0_0)
# A_o_0_1 =  ReLU(A_x_0_1)
# A_o_0_2 =  ReLU(A_x_0_2)
# A_o_0_3 =  ReLU(A_x_0_3)
# (A_x_1_0 = ((0.62615985 * A_o_0_0) + (0.039529245 * A_o_0_1) + (-0.5513049 * A_o_0_2) + (0.6923107 * A_o_0_3) + 0.022550788))
# (A_x_1_1 = ((-0.12951012 * A_o_0_0) + (0.22551966 * A_o_0_1) + (0.2794804 * A_o_0_2) + (-0.018626418 * A_o_0_3) + -0.18887858))
# (A_x_1_2 = ((-0.25555655 * A_o_0_0) + (1.0147316 * A_o_0_1) + (0.92903113 * A_o_0_2) + (-0.23300982 * A_o_0_3) + -0.103333026))
# (A_x_1_3 = ((-0.40417266 * A_o_0_0) + (-0.76209813 * A_o_0_1) + (-0.6888845 * A_o_0_2) + (0.59146595 * A_o_0_3) + 0.1664231))
# A_o_1_0 =  ReLU(A_x_1_0)
# A_o_1_1 =  ReLU(A_x_1_1)
# A_o_1_2 =  ReLU(A_x_1_2)
# A_o_1_3 =  ReLU(A_x_1_3)
# (A_x_2_0 = ((0.9111556 * A_o_1_0) + (-0.5999428 * A_o_1_1) + (-0.724907 * A_o_1_2) + (1.2218964 * A_o_1_3) + 0.105831355))
# (A_x_2_1 = ((0.5837674 * A_o_1_0) + (0.55900586 * A_o_1_1) + (-0.22997126 * A_o_1_2) + (-0.35976943 * A_o_1_3) + -0.16196148))
# (A_x_2_2 = ((-0.16923249 * A_o_1_0) + (0.49686074 * A_o_1_1) + (0.8652662 * A_o_1_2) + (0.08620654 * A_o_1_3) + 0.07103808))
# (B_x_0_0 = ((1.0 * i_0_0) + (0.07340504 * i_0_1) + (-0.21287224 * i_0_2) + (0.46451607 * i_0_3) + -0.21016687))
# (B_x_0_1 = ((-0.7547593 * i_0_0) + (1.0 * i_0_1) + (0.66521823 * i_0_2) + (0.31605786 * i_0_3) + 0.085867114))
# (B_x_0_2 = ((1.0 * i_0_0) + (-0.35396737 * i_0_1) + (0.122523874 * i_0_2) + (0.57615966 * i_0_3) + 0.23653667))
# (B_x_0_3 = ((0.42926562 * i_0_0) + (1.0 * i_0_1) + (-0.37910253 * i_0_2) + (0.016789414 * i_0_3) + 0.10610554))
# B_o_0_0 =  ReLU(B_x_0_0)
# B_o_0_1 =  ReLU(B_x_0_1)
# B_o_0_2 =  ReLU(B_x_0_2)
# B_o_0_3 =  ReLU(B_x_0_3)
# (B_x_1_0 = ((0.62615985 * B_o_0_0) + (0.039529245 * B_o_0_1) + (-0.5513049 * B_o_0_2) + (0.6923107 * B_o_0_3) + 0.022550788))
# (B_x_1_1 = ((-0.12951012 * B_o_0_0) + (0.22551966 * B_o_0_1) + (0.2794804 * B_o_0_2) + (-0.018626418 * B_o_0_3) + -0.18887858))
# (B_x_1_2 = ((-0.25555655 * B_o_0_0) + (1.0147316 * B_o_0_1) + (0.92903113 * B_o_0_2) + (-0.23300982 * B_o_0_3) + -0.103333026))
# (B_x_1_3 = ((-0.40417266 * B_o_0_0) + (-0.76209813 * B_o_0_1) + (-0.6888845 * B_o_0_2) + (0.59146595 * B_o_0_3) + 0.1664231))
# B_o_1_0 =  ReLU(B_x_1_0)
# B_o_1_1 =  ReLU(B_x_1_1)
# B_o_1_2 =  ReLU(B_x_1_2)
# B_o_1_3 =  ReLU(B_x_1_3)
# (B_x_2_0 = ((0.9111556 * B_o_1_0) + (-0.5999428 * B_o_1_1) + (-0.724907 * B_o_1_2) + (1.2218964 * B_o_1_3) + 0.105831355))
# (B_x_2_1 = ((0.5837674 * B_o_1_0) + (0.55900586 * B_o_1_1) + (-0.22997126 * B_o_1_2) + (-0.35976943 * B_o_1_3) + -0.16196148))
# (B_x_2_2 = ((-0.16923249 * B_o_1_0) + (0.49686074 * B_o_1_1) + (0.8652662 * B_o_1_2) + (0.08620654 * B_o_1_3) + 0.07103808))
# (E_diff_0_0 = (A_x_2_0 + (- B_x_2_0)))
# (E_diff_0_1 = (A_x_2_1 + (- B_x_2_1)))
# (E_diff_0_2 = (A_x_2_2 + (- B_x_2_2)))
# E_abs_d_0_0 =  |E_diff_0_0|
# E_abs_d_0_1 =  |E_diff_0_1|
# E_abs_d_0_2 =  |E_diff_0_2|
# E_y_0_0 = BinMult(E_pi_0_0, E_abs_d_0_0)
# E_y_1_0 = BinMult(E_pi_1_0, E_abs_d_0_1)
# E_y_2_0 = BinMult(E_pi_2_0, E_abs_d_0_2)
# (E_o_1_0 = (E_y_0_0 + E_y_1_0 + E_y_2_0))
# (1 = (E_pi_0_0 + E_pi_1_0 + E_pi_2_0))
# (E_set_1_0 = (E_pi_0_0))
# 1 >= E_set_1_0
# (E_set_1_1 = (E_pi_1_0))
# 1 >= E_set_1_1
# (E_set_1_2 = (E_pi_2_0))
# 1 >= E_set_1_2
# E_set_1_0 = 0 --> E_abs_d_0_0 <= E_o_1_0
# E_set_1_1 = 0 --> E_abs_d_0_1 <= E_o_1_0
# E_set_1_2 = 0 --> E_abs_d_0_2 <= E_o_1_0
# E_o_1_0 in top_1(E_abs_d_0_0, E_abs_d_0_1, E_abs_d_0_2)
# (E_norm_1_0 = E_o_1_0)

# %% [markdown]
# If we wanted to, we could again tighten the bounds using `enc.optimize_constraints()`,
# however, for a problem of small size, like the current one, we skip this step.
#
# Instead, we directly optimize the model.

# %%
model = enc.create_gurobi_model()
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 157 rows, 78 columns and 398 nonzeros
# Model fingerprint: 0x0ce91941
# Variable types: 53 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 2e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [2e-02, 2e+06]
# Presolve removed 45 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 112 rows, 67 columns, 326 nonzeros
# Variable types: 46 continuous, 21 integer (21 binary)
#
# Root relaxation: objective 2.725214e+01, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   27.25214    0   10          -   27.25214      -     -    0s
# H    0     0                       7.7829186   27.25214   250%     -    0s
#      0     0   26.63355    0   11    7.78292   26.63355   242%     -    0s
#      0     0   25.55570    0   11    7.78292   25.55570   228%     -    0s
#      0     0   25.55570    0   11    7.78292   25.55570   228%     -    0s
#      0     0   25.55570    0    7    7.78292   25.55570   228%     -    0s
#      0     0   25.37003    0    8    7.78292   25.37003   226%     -    0s
#      0     0   25.33140    0   12    7.78292   25.33140   225%     -    0s
#      0     0   25.30994    0   11    7.78292   25.30994   225%     -    0s
#      0     0   25.30925    0   11    7.78292   25.30925   225%     -    0s
#      0     0   24.81551    0   11    7.78292   24.81551   219%     -    0s
#      0     0   24.76004    0   12    7.78292   24.76004   218%     -    0s
#      0     0   24.76004    0   10    7.78292   24.76004   218%     -    0s
#      0     0   24.74249    0   11    7.78292   24.74249   218%     -    0s
#      0     0   24.73746    0   12    7.78292   24.73746   218%     -    0s
#      0     0   24.73127    0   11    7.78292   24.73127   218%     -    0s
#      0     0   24.73114    0   11    7.78292   24.73114   218%     -    0s
#      0     0   24.73060    0   11    7.78292   24.73060   218%     -    0s
#      0     0   24.73060    0   11    7.78292   24.73060   218%     -    0s
#      0     2   24.73060    0   11    7.78292   24.73060   218%     -    0s
# *   21     6               9       9.2406820   14.65829  58.6%  11.8    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#   MIR: 11
#   Flow cover: 7
#   RLT: 11
#
# Explored 31 nodes (588 simplex iterations) in 0.16 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 2: 9.24068 7.78292
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.240681994240e+00, best bound 9.240681994240e+00, gap 0.0000%

# %% [markdown]
# Gurobi solved the model to optimality and claims that the maximum Chebyshev distance between the reference and the test network is $9.24$.

# %%
from analysis import compare_outputs, calculate_distance

# %% [markdown]
# We obtain the maximizing input:

# %%
ins = get_grb_inputs(model, 4)
print(ins)
# Out:
# [5.0, 5.0, 5.0, 2.02225504080907]

# %% [markdown]
# With a quick check, we can confirm that indeed, the difference in the first output leads to a distance of $9.24$.

# %%
compare_outputs(reference, test, ins)
# Out:
# +--------+-------------------------+------------------------+
# | Neuron |          NN 1           |          NN 2          |
# +========+=========================+========================+
# | 0      | 6.669                   | (- 2.5716000255475517) |
# +--------+-------------------------+------------------------+
# | 1      | 1.138                   | 1.518                  |
# +--------+-------------------------+------------------------+
# | 2      | (- 0.35190319897864414) | 6.769                  |
# +--------+-------------------------+------------------------+

# %%
calculate_distance(ins, reference, test, mode='chebyshev')
# Out:
# 9.240681994240212

# %% [markdown]
# If we are only interested in checking whether $\| \mathcal{R}(x) - \mathcal{T}(x) \|_p \leq \delta$ for $p \in \{1, \infty\}$ and some constant $\delta$, we can also run the optimization as above, but stop execution as soon as either
# - an input was found that yields a larger distance in the specified norm or
# - the obtained upper bound on the distance is already $\leq \delta$.
#
# This can be achieved via

# %%
delta = 20

model = enc.create_gurobi_model()
model.setParam('BestObjStop', delta)
model.setParam('BestBdStop', delta)
model.optimize()
# Out:
# Set parameter BestObjStop to value 20
# Set parameter BestBdStop to value 20
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (linux64 - "Ubuntu 22.04.4 LTS")
#
# CPU model: Intel(R) Core(TM) i7-7500U CPU @ 2.70GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
#
# Optimize a model with 157 rows, 78 columns and 398 nonzeros
# Model fingerprint: 0x0ce91941
# Variable types: 53 continuous, 25 integer (25 binary)
# Coefficient statistics:
#   Matrix range     [2e-02, 2e+06]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 5e+00]
#   RHS range        [2e-02, 2e+06]
# Presolve removed 45 rows and 11 columns
# Presolve time: 0.00s
# Presolved: 112 rows, 67 columns, 326 nonzeros
# Variable types: 46 continuous, 21 integer (21 binary)
#
# Root relaxation: objective 2.725214e+01, 47 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0   27.25214    0   10          -   27.25214      -     -    0s
# H    0     0                       7.7829186   27.25214   250%     -    0s
#      0     0   26.63355    0   11    7.78292   26.63355   242%     -    0s
#      0     0   25.55570    0   11    7.78292   25.55570   228%     -    0s
#      0     0   25.55570    0   11    7.78292   25.55570   228%     -    0s
#      0     0   25.55570    0    7    7.78292   25.55570   228%     -    0s
#      0     0   25.37003    0    8    7.78292   25.37003   226%     -    0s
#      0     0   25.33140    0   12    7.78292   25.33140   225%     -    0s
#      0     0   25.30994    0   11    7.78292   25.30994   225%     -    0s
#      0     0   25.30925    0   11    7.78292   25.30925   225%     -    0s
#      0     0   24.81551    0   11    7.78292   24.81551   219%     -    0s
#      0     0   24.76004    0   12    7.78292   24.76004   218%     -    0s
#      0     0   24.76004    0   10    7.78292   24.76004   218%     -    0s
#      0     0   24.74249    0   11    7.78292   24.74249   218%     -    0s
#      0     0   24.73746    0   12    7.78292   24.73746   218%     -    0s
#      0     0   24.73127    0   11    7.78292   24.73127   218%     -    0s
#      0     0   24.73114    0   11    7.78292   24.73114   218%     -    0s
#      0     0   24.73060    0   11    7.78292   24.73060   218%     -    0s
#      0     0   24.73060    0   11    7.78292   24.73060   218%     -    0s
#      0     2   24.73060    0   11    7.78292   24.73060   218%     -    0s
#
# Cutting planes:
#   Gomory: 2
#   Implied bound: 1
#   MIR: 8
#   Flow cover: 7
#   RLT: 8
#
# Explored 9 nodes (461 simplex iterations) in 0.15 seconds (0.05 work units)
# Thread count was 4 (of 4 available processors)
#
# Solution count 1: 7.78292
#
# Optimization achieved user objective limit
# Best objective 7.782918599076e+00, best bound 1.465828573028e+01, gap 88.3392%

# %% [markdown]
# In this setting, the optimization was stopped, because the current upper bound of $14.66$ is smaller than the specified value of $\delta = 20$.
